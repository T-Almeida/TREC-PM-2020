# %%
import tempfile
import sys
import subprocess
import shutil
from os.path import join
from elasticsearch import Elasticsearch, helpers
from nir.utils import create_filter_query_function, change_bm25_parameters
from mmnrm.text import TREC_goldstandard_transform, TREC_queries_transform, TREC_results_transform
from mmnrm.dataset import TestCollectionV2
from mmnrm.evaluation import TREC_Evaluator
import pickle

import json

es = Elasticsearch(["http://193.136.175.98:8125"])

index_name = "trec-pm-2020-synonym"

# %%
def load_TREC_qrels(q_rels_file):
    
    with open(q_rels_file) as f:
        goldstandard = defaultdict(list)

        for line in f:
            line = line.strip().split(" ")
            try:
                goldstandard[line[0]].append((line[2], line[3]))
            except :
                print(line)
            
    return TREC_goldstandard_transform(goldstandard)


import xmltodict
import ctypes
from collections import defaultdict

def load_TREC_topics(topics_file):
    with open(topics_file) as f:
        xml_dict=xmltodict.parse(f.read())["topics"]["topic"]

    topics_json = []

    for topic in xml_dict:
        topics_json.append({"id":topic["@number"],
                           "disease":topic["disease"],
                           "gene":topic["gene"],
                           "demographic":topic["demographic"]})

    return TREC_queries_transform(topics_json, number_parameter="id", fn=lambda x:x["disease"]+" "+x["gene"])

# %%
topics = load_TREC_topics("topics2019.xml")
#qrels = load_TREC_qrels("qrels-treceval-abstracts.2019.txt")

# %%
def execute_queries(queries, fields, analyzer, top_k=1000):
    filter_query_string = create_filter_query_function()

    documents = {}

    for j,query_data in enumerate(queries):

        if not j%10:
            print(j, end="\r")

        query = filter_query_string(query_data["query"])
        query_es = {
                  "query": {
                    "bool": {
                      "must": [
                        {
                          "query_string": {
                            "query": query, 
                            "analyzer": analyzer,
                            "fields": fields
                          }
                        }
                      ], 
                      "filter": [], 
                      "should": [], 
                      "must_not": []
                    }
                  }
                }



        retrieved = es.search(index=index_name, body=query_es, size=top_k, request_timeout=200)

        documents[query_data["id"]] = list(map(lambda x:{"id":x["_source"]["id"], 
                                                         "text":x["_source"]["text"],
                                                         "title":x["_source"]["title"],
                                                         "score":x['_score']}, retrieved['hits']['hits']))

        # just to ensure the elastic search order is mantained
        validate_order = lambda x:all(x[i] >= x[i+1] for i in range(len(x)-1))
        assert validate_order(list(map(lambda x: x['_score'], retrieved['hits']['hits'])))
        
    return documents

# %%
#K1 = [ round(0.5 + (i*0.2),1) for i in range(int((3.0-0.5)/0.2)+1)]
#B = [ round(0.3 + (i*0.1),1) for i in range(int((0.9-0.3)/0.1)+1)]
K1 = [0.5, 1.5, 2.5]
B = [0.3,0.7] 

FIELDS = [ ["text"]]#, ["text","mesh_terms"]]
#ANALYSER = ["english", "gene_synonym_all", "gene_synonym_symbol", "gene_synonym_symbol_ortho"]
ANALYSER = ["english", "gene_synonym_symbol", "gene_synonym_complete_symbols", "gene_synonym_NCBI"]
output_metris=["recall_100","recall_500","recall_1000", "map_cut_1000", "ndcg_cut_10", "P_5"]

def save_answers_to_file(answers, prefix = None, out_file = None):
    if out_file is not None:
        _name = out_file
    elif prefix is not None:
        _name = name.split(".")[0]+"_answer.txt"
    else:
        raise ValueError("set prefix or out_file")
        
    with open(_name,"w", encoding="utf-8") as f:
        for line in answers:
            f.write(line+"\n")
        
    return _name

with open("bm25_"+index_name+".csv", "w") as f:
    f.write("k1,b,fields,analyser,"+",".join(output_metris)+"\n")
    c = 0
    for fields in FIELDS:
        for analyser in ANALYSER:
            for i,k in enumerate(K1):
                for j,b in enumerate(B):
                    # update bm25
                    print(c,"/",len(K1)*len(B)*len(ANALYSER)*len(FIELDS))
                    #print(fields, analyser, k , b)
                    change_bm25_parameters(k, b, index_name, es)

                    retrieved = execute_queries(topics, fields, analyser)
                    """
                    answers = []
                    for _q in q:
                        for i,doc_info in enumerate(retrieved[_q["id"]]):
                            answers.append("{} Q0 {} {} {} {}".format(_q["id"],
                                                             doc_info["id"],
                                                             i+1,
                                                             doc_info["score"],
                                                             "test"))

                    save_answers_to_file(answers, out_file="test.txt")
                    """

                    trec_evaluator = TREC_Evaluator("qrels-treceval-abstracts.2019.txt", '/backup/TREC/TestSet/trec_eval-9.0.7/trec_eval')
                    test_collection = TestCollectionV2(topics, retrieved, trec_evaluator).batch_size(100)

                    metrics = test_collection.evaluate_pre_rerank(output_metris=output_metris)

                    list_metrics = [ metrics[m] for m in output_metris]

                    str_placeholder = "{},{},{},{}," + (("{:.4f},"*len(list_metrics))[:-1]) +"\n"

                    f.write(str_placeholder.format(k,b,"_".join(fields), analyser, *(list_metrics)))
                    c+=1
# Out:
# 0 / 24
# Remove /tmp/tmpnjqnfzo2
# 1 / 24
# Remove /tmp/tmpyeaa4jpe
# 2 / 24
# Remove /tmp/tmp80_7d39x
# 3 / 24
# Remove /tmp/tmpewi7_9kb
# 4 / 24
# Remove /tmp/tmpl84ahjci
# 5 / 24
# Remove /tmp/tmp6b1jdbl7
# 6 / 24
# Remove /tmp/tmpsz6y1a35
# 7 / 24
# Remove /tmp/tmpl17rtilf
# 8 / 24
# Remove /tmp/tmp86updp5x
# 9 / 24
# Remove /tmp/tmpmwplngz1
# 10 / 24
# Remove /tmp/tmps5gzbvzw
# 11 / 24
# Remove /tmp/tmpiwxz2b32
# 12 / 24
# Remove /tmp/tmp83gzhnf3
# 13 / 24
# Remove /tmp/tmpazvye5er
# 14 / 24
# Remove /tmp/tmphi7h1j9v
# 15 / 24
# Remove /tmp/tmpsn6hyl91
# 16 / 24
# Remove /tmp/tmpayo09t7o
# 17 / 24
# Remove /tmp/tmptfzcrtry
# 18 / 24
# Remove /tmp/tmp2aalpqp4
# 19 / 24
# Remove /tmp/tmpt7hr1ahs
# 20 / 24
# Remove /tmp/tmpfbaye6rl
# 21 / 24
# Remove /tmp/tmpym0ntxxc
# 22 / 24
# Remove /tmp/tmp2zot1_0n
# 23 / 24
# Remove /tmp/tmpq_ex8bg_

# %%
import pandas as pd

#df = pd.read_csv("bm25_trec-pm-2020-synonym-no-k1-b.csv")
df = pd.read_csv("bm25_trec-pm-2020-synonym.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 10 columns):
# k1              24 non-null float64
# b               24 non-null float64
# fields          24 non-null object
# analyser        24 non-null object
# recall_100      24 non-null float64
# recall_500      24 non-null float64
# recall_1000     24 non-null float64
# map_cut_1000    24 non-null float64
# ndcg_cut_10     24 non-null float64
# P_5             24 non-null float64
# dtypes: float64(8), object(2)
# memory usage: 2.0+ KB

# %%
df.sort_values(by=["recall_500"],ascending=False )
#0.9 0.7
# Out:
#       k1    b fields             analyser  recall_100  recall_500  \
# 17   0.9  0.6   text              english      0.3751      0.6994
# 1    0.5  0.4   text              english      0.3766      0.6987
# 3    0.5  0.6   text              english      0.3788      0.6986
# 18   0.9  0.7   text              english      0.3751      0.6985
# 0    0.5  0.3   text              english      0.3758      0.6982
# 9    0.7  0.5   text              english      0.3772      0.6982
# 2    0.5  0.5   text              english      0.3796      0.6977
# 8    0.7  0.4   text              english      0.3752      0.6975
# 15   0.9  0.4   text              english      0.3725      0.6970
# 19   0.9  0.8   text              english      0.3746      0.6968
# 16   0.9  0.5   text              english      0.3772      0.6968
# 7    0.7  0.3   text              english      0.3726      0.6966
# 14   0.9  0.3   text              english      0.3720      0.6964
# 22   1.1  0.4   text              english      0.3718      0.6962
# 4    0.5  0.7   text              english      0.3796      0.6960
# 10   0.7  0.6   text              english      0.3784      0.6960
# 23   1.1  0.5   text              english      0.3738      0.6957
# 113  1.1  0.4   text  gene_synonym_symbol      0.3574      0.6955
# 11   0.7  0.7   text              english      0.3825      0.6953
# 121  1.3  0.5   text  gene_synonym_symbol      0.3574      0.6952
# 5    0.5  0.8   text              english      0.3726      0.6952
# 106  0.9  0.4   text  gene_synonym_symbol      0.3570      0.6948
# 128  1.5  0.5   text  gene_synonym_symbol      0.3569      0.6947
# 164  2.5  0.6   text  gene_synonym_symbol      0.3523      0.6946
# 24   1.1  0.6   text              english      0.3754      0.6942
# 112  1.1  0.3   text  gene_synonym_symbol      0.3573      0.6941
# 12   0.7  0.8   text              english      0.3749      0.6937
# 171  2.7  0.6   text  gene_synonym_symbol      0.3516      0.6936
# 143  1.9  0.6   text  gene_synonym_symbol      0.3549      0.6935
# 172  2.7  0.7   text  gene_synonym_symbol      0.3501      0.6934
# ..   ...  ...    ...                  ...         ...         ...
# 66   2.3  0.6   text              english      0.3496      0.6729
# 62   2.1  0.9   text              english      0.3540      0.6724
# 75   2.5  0.8   text              english      0.3467      0.6716
# 69   2.3  0.9   text              english      0.3461      0.6714
# 50   1.9  0.4   text              english      0.3593      0.6714
# 76   2.5  0.9   text              english      0.3441      0.6699
# 65   2.3  0.5   text              english      0.3472      0.6685
# 57   2.1  0.4   text              english      0.3497      0.6676
# 73   2.5  0.6   text              english      0.3476      0.6674
# 49   1.9  0.3   text              english      0.3577      0.6673
# 83   2.7  0.9   text              english      0.3391      0.6668
# 82   2.7  0.8   text              english      0.3428      0.6663
# 81   2.7  0.7   text              english      0.3376      0.6661
# 56   2.1  0.3   text              english      0.3463      0.6656
# 64   2.3  0.4   text              english      0.3429      0.6650
# 72   2.5  0.5   text              english      0.3445      0.6633
# 80   2.7  0.6   text              english      0.3441      0.6629
# 88   2.9  0.7   text              english      0.3362      0.6628
# 90   2.9  0.9   text              english      0.3371      0.6616
# 89   2.9  0.8   text              english      0.3406      0.6611
# 87   2.9  0.6   text              english      0.3422      0.6604
# 71   2.5  0.4   text              english      0.3403      0.6601
# 63   2.3  0.3   text              english      0.3411      0.6599
# 79   2.7  0.5   text              english      0.3400      0.6597
# 70   2.5  0.3   text              english      0.3403      0.6566
# 78   2.7  0.4   text              english      0.3385      0.6566
# 86   2.9  0.5   text              english      0.3380      0.6555
# 77   2.7  0.3   text              english      0.3384      0.6517
# 85   2.9  0.4   text              english      0.3390      0.6511
# 84   2.9  0.3   text              english      0.3333      0.6453
#
#      recall_1000  map_cut_1000  ndcg_cut_10    P_5
# 17        0.7911        0.2929       0.5190  0.525
# 1         0.7901        0.2915       0.5139  0.545
# 3         0.7906        0.2915       0.5250  0.535
# 18        0.7916        0.2917       0.5187  0.530
# 0         0.7902        0.2913       0.5216  0.545
# 9         0.7902        0.2931       0.5195  0.540
# 2         0.7908        0.2920       0.5184  0.545
# 8         0.7913        0.2925       0.5142  0.540
# 15        0.7893        0.2918       0.5101  0.530
# 19        0.7905        0.2906       0.5303  0.545
# 16        0.7914        0.2929       0.5163  0.535
# 7         0.7899        0.2919       0.5190  0.535
# 14        0.7893        0.2913       0.5168  0.535
# 22        0.7902        0.2903       0.5044  0.525
# 4         0.7907        0.2901       0.5281  0.535
# 10        0.7898        0.2928       0.5253  0.530
# 23        0.7911        0.2911       0.5100  0.520
# 113       0.7908        0.2818       0.4923  0.530
# 11        0.7894        0.2913       0.5241  0.525
# 121       0.7907        0.2827       0.4891  0.530
# 5         0.7894        0.2889       0.5376  0.550
# 106       0.7881        0.2803       0.4965  0.545
# 128       0.7915        0.2828       0.4877  0.530
# 164       0.7936        0.2792       0.4759  0.520
# 24        0.7908        0.2916       0.5152  0.525
# 112       0.7910        0.2811       0.4956  0.515
# 12        0.7875        0.2899       0.5332  0.540
# 171       0.7930        0.2783       0.4731  0.520
# 143       0.7911        0.2807       0.4873  0.520
# 172       0.7928        0.2772       0.4769  0.545
# ..           ...           ...          ...    ...
# 66        0.7709        0.2797       0.5081  0.545
# 62        0.7723        0.2770       0.5205  0.555
# 75        0.7651        0.2764       0.5158  0.545
# 69        0.7642        0.2749       0.5231  0.555
# 50        0.7739        0.2813       0.4969  0.545
# 76        0.7616        0.2728       0.5242  0.555
# 65        0.7694        0.2778       0.5007  0.545
# 57        0.7712        0.2786       0.5010  0.545
# 73        0.7690        0.2758       0.5004  0.545
# 49        0.7737        0.2789       0.5018  0.540
# 83        0.7584        0.2704       0.5213  0.560
# 82        0.7629        0.2739       0.5147  0.550
# 81        0.7667        0.2738       0.5019  0.535
# 56        0.7688        0.2756       0.5012  0.540
# 64        0.7693        0.2758       0.5006  0.545
# 72        0.7664        0.2743       0.4948  0.545
# 80        0.7640        0.2730       0.5009  0.545
# 88        0.7640        0.2713       0.5025  0.545
# 90        0.7531        0.2680       0.5178  0.550
# 89        0.7612        0.2713       0.5136  0.550
# 87        0.7624        0.2706       0.5000  0.550
# 71        0.7667        0.2724       0.4973  0.550
# 63        0.7672        0.2725       0.5000  0.545
# 79        0.7642        0.2714       0.4947  0.555
# 70        0.7630        0.2695       0.5011  0.545
# 78        0.7627        0.2690       0.4991  0.545
# 86        0.7622        0.2688       0.4957  0.550
# 77        0.7557        0.2658       0.4986  0.540
# 85        0.7599        0.2662       0.4993  0.545
# 84        0.7537        0.2631       0.4959  0.545
#
# [182 rows x 10 columns]

# %%
df.sort_values(by=["recall_100"],ascending=False )
# Out:
#      k1    b                    fields                   analyser  recall_100  \
# 73  0.5  0.7  text_keywords_mesh_terms                    english      0.3816
# 49  0.5  0.7             text_keywords                    english      0.3816
# 1   0.5  0.7                      text                    english      0.3816
# 25  0.5  0.7           text_mesh_terms                    english      0.3816
# 0   0.5  0.3                      text                    english      0.3770
# 24  0.5  0.3           text_mesh_terms                    english      0.3770
# 72  0.5  0.3  text_keywords_mesh_terms                    english      0.3770
# 48  0.5  0.3             text_keywords                    english      0.3770
# 74  1.5  0.3  text_keywords_mesh_terms                    english      0.3658
# 2   1.5  0.3                      text                    english      0.3658
# 26  1.5  0.3           text_mesh_terms                    english      0.3658
# 50  1.5  0.3             text_keywords                    english      0.3658
# 13  0.5  0.7                      text        gene_synonym_symbol      0.3655
# 37  0.5  0.7           text_mesh_terms        gene_synonym_symbol      0.3655
# 51  1.5  0.7             text_keywords                    english      0.3644
# 75  1.5  0.7  text_keywords_mesh_terms                    english      0.3644
# 27  1.5  0.7           text_mesh_terms                    english      0.3644
# 3   1.5  0.7                      text                    english      0.3644
# 12  0.5  0.3                      text        gene_synonym_symbol      0.3626
# 36  0.5  0.3           text_mesh_terms        gene_synonym_symbol      0.3626
# 61  0.5  0.7             text_keywords        gene_synonym_symbol      0.3583
# 85  0.5  0.7  text_keywords_mesh_terms        gene_synonym_symbol      0.3583
# 60  0.5  0.3             text_keywords        gene_synonym_symbol      0.3565
# 84  0.5  0.3  text_keywords_mesh_terms        gene_synonym_symbol      0.3565
# 14  1.5  0.3                      text        gene_synonym_symbol      0.3425
# 38  1.5  0.3           text_mesh_terms        gene_synonym_symbol      0.3425
# 86  1.5  0.3  text_keywords_mesh_terms        gene_synonym_symbol      0.3416
# 62  1.5  0.3             text_keywords        gene_synonym_symbol      0.3416
# 52  2.5  0.3             text_keywords                    english      0.3414
# 28  2.5  0.3           text_mesh_terms                    english      0.3414
# ..  ...  ...                       ...                        ...         ...
# 69  1.5  0.7             text_keywords  gene_synonym_symbol_ortho      0.2625
# 47  2.5  0.7           text_mesh_terms  gene_synonym_symbol_ortho      0.2621
# 23  2.5  0.7                      text  gene_synonym_symbol_ortho      0.2620
# 67  0.5  0.7             text_keywords  gene_synonym_symbol_ortho      0.2599
# 95  2.5  0.7  text_keywords_mesh_terms  gene_synonym_symbol_ortho      0.2575
# 71  2.5  0.7             text_keywords  gene_synonym_symbol_ortho      0.2574
# 8   1.5  0.3                      text           gene_synonym_all      0.1536
# 32  1.5  0.3           text_mesh_terms           gene_synonym_all      0.1522
# 11  2.5  0.7                      text           gene_synonym_all      0.1500
# 35  2.5  0.7           text_mesh_terms           gene_synonym_all      0.1499
# 10  2.5  0.3                      text           gene_synonym_all      0.1492
# 33  1.5  0.7           text_mesh_terms           gene_synonym_all      0.1490
# 34  2.5  0.3           text_mesh_terms           gene_synonym_all      0.1486
# 9   1.5  0.7                      text           gene_synonym_all      0.1485
# 6   0.5  0.3                      text           gene_synonym_all      0.1465
# 59  2.5  0.7             text_keywords           gene_synonym_all      0.1458
# 83  2.5  0.7  text_keywords_mesh_terms           gene_synonym_all      0.1458
# 56  1.5  0.3             text_keywords           gene_synonym_all      0.1457
# 80  1.5  0.3  text_keywords_mesh_terms           gene_synonym_all      0.1446
# 58  2.5  0.3             text_keywords           gene_synonym_all      0.1442
# 82  2.5  0.3  text_keywords_mesh_terms           gene_synonym_all      0.1436
# 30  0.5  0.3           text_mesh_terms           gene_synonym_all      0.1430
# 7   0.5  0.7                      text           gene_synonym_all      0.1428
# 81  1.5  0.7  text_keywords_mesh_terms           gene_synonym_all      0.1411
# 31  0.5  0.7           text_mesh_terms           gene_synonym_all      0.1409
# 57  1.5  0.7             text_keywords           gene_synonym_all      0.1403
# 79  0.5  0.7  text_keywords_mesh_terms           gene_synonym_all      0.1206
# 55  0.5  0.7             text_keywords           gene_synonym_all      0.1189
# 78  0.5  0.3  text_keywords_mesh_terms           gene_synonym_all      0.1176
# 54  0.5  0.3             text_keywords           gene_synonym_all      0.1168
#
#     recall_500  recall_1000  map_cut_1000  ndcg_cut_10    P_5
# 73      0.6759       0.7757        0.2943       0.5232  0.560
# 49      0.6759       0.7761        0.2944       0.5232  0.560
# 1       0.6765       0.7761        0.2945       0.5232  0.560
# 25      0.6765       0.7757        0.2944       0.5232  0.560
# 0       0.6799       0.7815        0.2971       0.5300  0.545
# 24      0.6799       0.7813        0.2971       0.5300  0.545
# 72      0.6796       0.7813        0.2971       0.5300  0.545
# 48      0.6796       0.7815        0.2971       0.5300  0.545
# 74      0.6606       0.7673        0.2856       0.5072  0.540
# 2       0.6606       0.7678        0.2856       0.5072  0.540
# 26      0.6606       0.7673        0.2856       0.5072  0.540
# 50      0.6606       0.7678        0.2856       0.5072  0.540
# 13      0.6748       0.7648        0.2678       0.5118  0.530
# 37      0.6748       0.7637        0.2675       0.5118  0.530
# 51      0.6572       0.7569        0.2804       0.5084  0.580
# 75      0.6572       0.7571        0.2804       0.5084  0.580
# 27      0.6572       0.7571        0.2804       0.5084  0.580
# 3       0.6572       0.7569        0.2804       0.5084  0.580
# 12      0.6752       0.7683        0.2730       0.5083  0.535
# 36      0.6755       0.7674        0.2729       0.5083  0.535
# 61      0.6748       0.7648        0.2610       0.4965  0.510
# 85      0.6745       0.7637        0.2608       0.4965  0.510
# 60      0.6752       0.7683        0.2664       0.4951  0.515
# 84      0.6755       0.7671        0.2663       0.4951  0.515
# 14      0.6534       0.7570        0.2581       0.4651  0.515
# 38      0.6534       0.7570        0.2581       0.4651  0.515
# 86      0.6534       0.7570        0.2574       0.4651  0.515
# 62      0.6534       0.7570        0.2574       0.4651  0.515
# 52      0.6362       0.7390        0.2649       0.4876  0.545
# 28      0.6362       0.7390        0.2649       0.4876  0.545
# ..         ...          ...           ...          ...    ...
# 69      0.5723       0.6665        0.1668       0.2864  0.315
# 47      0.5566       0.6559        0.1673       0.3166  0.380
# 23      0.5561       0.6553        0.1672       0.3166  0.380
# 67      0.5802       0.6705        0.1639       0.2820  0.335
# 95      0.5562       0.6560        0.1622       0.3018  0.355
# 71      0.5557       0.6554        0.1621       0.3018  0.355
# 8       0.3632       0.4719        0.0753       0.1571  0.185
# 32      0.3650       0.4791        0.0763       0.1579  0.185
# 11      0.3532       0.4571        0.0721       0.1542  0.210
# 35      0.3535       0.4588        0.0721       0.1542  0.210
# 10      0.3605       0.4603        0.0741       0.1613  0.170
# 33      0.3590       0.4702        0.0739       0.1664  0.195
# 34      0.3598       0.4651        0.0739       0.1613  0.170
# 9       0.3581       0.4649        0.0733       0.1649  0.195
# 6       0.3380       0.4495        0.0694       0.1670  0.200
# 59      0.3522       0.4563        0.0672       0.1333  0.170
# 83      0.3522       0.4576        0.0672       0.1333  0.170
# 56      0.3582       0.4681        0.0694       0.1338  0.150
# 80      0.3609       0.4749        0.0705       0.1346  0.150
# 58      0.3590       0.4592        0.0699       0.1492  0.150
# 82      0.3586       0.4642        0.0697       0.1492  0.150
# 30      0.3449       0.4568        0.0696       0.1450  0.165
# 7       0.3401       0.4577        0.0688       0.1721  0.210
# 81      0.3559       0.4669        0.0673       0.1320  0.155
# 31      0.3465       0.4690        0.0709       0.1582  0.200
# 57      0.3547       0.4624        0.0667       0.1304  0.155
# 79      0.3308       0.4630        0.0614       0.1183  0.150
# 55      0.3236       0.4506        0.0577       0.1170  0.145
# 78      0.3366       0.4494        0.0615       0.1123  0.125
# 54      0.3309       0.4431        0.0594       0.1164  0.135
#
# [96 rows x 10 columns]

# %%
df.sort_values(by=["P_5"],ascending=False )
# Out:
#      k1    b                    fields                   analyser  recall_100  \
# 53  2.5  0.7             text_keywords                    english      0.3341
# 51  1.5  0.7             text_keywords                    english      0.3644
# 77  2.5  0.7  text_keywords_mesh_terms                    english      0.3341
# 3   1.5  0.7                      text                    english      0.3644
# 27  1.5  0.7           text_mesh_terms                    english      0.3644
# 5   2.5  0.7                      text                    english      0.3341
# 75  1.5  0.7  text_keywords_mesh_terms                    english      0.3644
# 29  2.5  0.7           text_mesh_terms                    english      0.3341
# 1   0.5  0.7                      text                    english      0.3816
# 49  0.5  0.7             text_keywords                    english      0.3816
# 25  0.5  0.7           text_mesh_terms                    english      0.3816
# 73  0.5  0.7  text_keywords_mesh_terms                    english      0.3816
# 52  2.5  0.3             text_keywords                    english      0.3414
# 24  0.5  0.3           text_mesh_terms                    english      0.3770
# 72  0.5  0.3  text_keywords_mesh_terms                    english      0.3770
# 28  2.5  0.3           text_mesh_terms                    english      0.3414
# 76  2.5  0.3  text_keywords_mesh_terms                    english      0.3414
# 0   0.5  0.3                      text                    english      0.3770
# 48  0.5  0.3             text_keywords                    english      0.3770
# 4   2.5  0.3                      text                    english      0.3414
# 2   1.5  0.3                      text                    english      0.3658
# 26  1.5  0.3           text_mesh_terms                    english      0.3658
# 74  1.5  0.3  text_keywords_mesh_terms                    english      0.3658
# 50  1.5  0.3             text_keywords                    english      0.3658
# 36  0.5  0.3           text_mesh_terms        gene_synonym_symbol      0.3626
# 12  0.5  0.3                      text        gene_synonym_symbol      0.3626
# 13  0.5  0.7                      text        gene_synonym_symbol      0.3655
# 37  0.5  0.7           text_mesh_terms        gene_synonym_symbol      0.3655
# 17  2.5  0.7                      text        gene_synonym_symbol      0.3111
# 65  2.5  0.7             text_keywords        gene_synonym_symbol      0.3111
# ..  ...  ...                       ...                        ...         ...
# 66  0.5  0.3             text_keywords  gene_synonym_symbol_ortho      0.2653
# 68  1.5  0.3             text_keywords  gene_synonym_symbol_ortho      0.2779
# 69  1.5  0.7             text_keywords  gene_synonym_symbol_ortho      0.2625
# 91  0.5  0.7  text_keywords_mesh_terms  gene_synonym_symbol_ortho      0.2630
# 90  0.5  0.3  text_keywords_mesh_terms  gene_synonym_symbol_ortho      0.2687
# 93  1.5  0.7  text_keywords_mesh_terms  gene_synonym_symbol_ortho      0.2629
# 11  2.5  0.7                      text           gene_synonym_all      0.1500
# 7   0.5  0.7                      text           gene_synonym_all      0.1428
# 35  2.5  0.7           text_mesh_terms           gene_synonym_all      0.1499
# 31  0.5  0.7           text_mesh_terms           gene_synonym_all      0.1409
# 6   0.5  0.3                      text           gene_synonym_all      0.1465
# 9   1.5  0.7                      text           gene_synonym_all      0.1485
# 33  1.5  0.7           text_mesh_terms           gene_synonym_all      0.1490
# 8   1.5  0.3                      text           gene_synonym_all      0.1536
# 32  1.5  0.3           text_mesh_terms           gene_synonym_all      0.1522
# 10  2.5  0.3                      text           gene_synonym_all      0.1492
# 59  2.5  0.7             text_keywords           gene_synonym_all      0.1458
# 83  2.5  0.7  text_keywords_mesh_terms           gene_synonym_all      0.1458
# 34  2.5  0.3           text_mesh_terms           gene_synonym_all      0.1486
# 30  0.5  0.3           text_mesh_terms           gene_synonym_all      0.1430
# 57  1.5  0.7             text_keywords           gene_synonym_all      0.1403
# 81  1.5  0.7  text_keywords_mesh_terms           gene_synonym_all      0.1411
# 82  2.5  0.3  text_keywords_mesh_terms           gene_synonym_all      0.1436
# 80  1.5  0.3  text_keywords_mesh_terms           gene_synonym_all      0.1446
# 79  0.5  0.7  text_keywords_mesh_terms           gene_synonym_all      0.1206
# 58  2.5  0.3             text_keywords           gene_synonym_all      0.1442
# 56  1.5  0.3             text_keywords           gene_synonym_all      0.1457
# 55  0.5  0.7             text_keywords           gene_synonym_all      0.1189
# 54  0.5  0.3             text_keywords           gene_synonym_all      0.1168
# 78  0.5  0.3  text_keywords_mesh_terms           gene_synonym_all      0.1176
#
#     recall_500  recall_1000  map_cut_1000  ndcg_cut_10    P_5
# 53      0.6298       0.7248        0.2599       0.4859  0.580
# 51      0.6572       0.7569        0.2804       0.5084  0.580
# 77      0.6298       0.7248        0.2599       0.4859  0.580
# 3       0.6572       0.7569        0.2804       0.5084  0.580
# 27      0.6572       0.7571        0.2804       0.5084  0.580
# 5       0.6298       0.7248        0.2599       0.4859  0.580
# 75      0.6572       0.7571        0.2804       0.5084  0.580
# 29      0.6298       0.7248        0.2599       0.4859  0.580
# 1       0.6765       0.7761        0.2945       0.5232  0.560
# 49      0.6759       0.7761        0.2944       0.5232  0.560
# 25      0.6765       0.7757        0.2944       0.5232  0.560
# 73      0.6759       0.7757        0.2943       0.5232  0.560
# 52      0.6362       0.7390        0.2649       0.4876  0.545
# 24      0.6799       0.7813        0.2971       0.5300  0.545
# 72      0.6796       0.7813        0.2971       0.5300  0.545
# 28      0.6362       0.7390        0.2649       0.4876  0.545
# 76      0.6362       0.7390        0.2649       0.4876  0.545
# 0       0.6799       0.7815        0.2971       0.5300  0.545
# 48      0.6796       0.7815        0.2971       0.5300  0.545
# 4       0.6362       0.7390        0.2649       0.4876  0.545
# 2       0.6606       0.7678        0.2856       0.5072  0.540
# 26      0.6606       0.7673        0.2856       0.5072  0.540
# 74      0.6606       0.7673        0.2856       0.5072  0.540
# 50      0.6606       0.7678        0.2856       0.5072  0.540
# 36      0.6755       0.7674        0.2729       0.5083  0.535
# 12      0.6752       0.7683        0.2730       0.5083  0.535
# 13      0.6748       0.7648        0.2678       0.5118  0.530
# 37      0.6748       0.7637        0.2675       0.5118  0.530
# 17      0.6188       0.7217        0.2347       0.4604  0.525
# 65      0.6188       0.7214        0.2347       0.4604  0.525
# ..         ...          ...           ...          ...    ...
# 66      0.5821       0.6760        0.1685       0.2769  0.325
# 68      0.5798       0.6781        0.1730       0.2903  0.325
# 69      0.5723       0.6665        0.1668       0.2864  0.315
# 91      0.5909       0.6768        0.1679       0.2789  0.315
# 90      0.5932       0.6799        0.1725       0.2614  0.300
# 93      0.5745       0.6692        0.1672       0.2820  0.300
# 11      0.3532       0.4571        0.0721       0.1542  0.210
# 7       0.3401       0.4577        0.0688       0.1721  0.210
# 35      0.3535       0.4588        0.0721       0.1542  0.210
# 31      0.3465       0.4690        0.0709       0.1582  0.200
# 6       0.3380       0.4495        0.0694       0.1670  0.200
# 9       0.3581       0.4649        0.0733       0.1649  0.195
# 33      0.3590       0.4702        0.0739       0.1664  0.195
# 8       0.3632       0.4719        0.0753       0.1571  0.185
# 32      0.3650       0.4791        0.0763       0.1579  0.185
# 10      0.3605       0.4603        0.0741       0.1613  0.170
# 59      0.3522       0.4563        0.0672       0.1333  0.170
# 83      0.3522       0.4576        0.0672       0.1333  0.170
# 34      0.3598       0.4651        0.0739       0.1613  0.170
# 30      0.3449       0.4568        0.0696       0.1450  0.165
# 57      0.3547       0.4624        0.0667       0.1304  0.155
# 81      0.3559       0.4669        0.0673       0.1320  0.155
# 82      0.3586       0.4642        0.0697       0.1492  0.150
# 80      0.3609       0.4749        0.0705       0.1346  0.150
# 79      0.3308       0.4630        0.0614       0.1183  0.150
# 58      0.3590       0.4592        0.0699       0.1492  0.150
# 56      0.3582       0.4681        0.0694       0.1338  0.150
# 55      0.3236       0.4506        0.0577       0.1170  0.145
# 54      0.3309       0.4431        0.0594       0.1164  0.135
# 78      0.3366       0.4494        0.0615       0.1123  0.125
#
# [96 rows x 10 columns]

# %%
df.sort_values(by=["map_cut_1000"],ascending=False )
# Out:
#      k1    b                    fields                   analyser  recall_100  \
# 0   0.5  0.3                      text                    english      0.3770
# 24  0.5  0.3           text_mesh_terms                    english      0.3770
# 72  0.5  0.3  text_keywords_mesh_terms                    english      0.3770
# 48  0.5  0.3             text_keywords                    english      0.3770
# 1   0.5  0.7                      text                    english      0.3816
# 25  0.5  0.7           text_mesh_terms                    english      0.3816
# 49  0.5  0.7             text_keywords                    english      0.3816
# 73  0.5  0.7  text_keywords_mesh_terms                    english      0.3816
# 50  1.5  0.3             text_keywords                    english      0.3658
# 26  1.5  0.3           text_mesh_terms                    english      0.3658
# 74  1.5  0.3  text_keywords_mesh_terms                    english      0.3658
# 2   1.5  0.3                      text                    english      0.3658
# 27  1.5  0.7           text_mesh_terms                    english      0.3644
# 51  1.5  0.7             text_keywords                    english      0.3644
# 3   1.5  0.7                      text                    english      0.3644
# 75  1.5  0.7  text_keywords_mesh_terms                    english      0.3644
# 12  0.5  0.3                      text        gene_synonym_symbol      0.3626
# 36  0.5  0.3           text_mesh_terms        gene_synonym_symbol      0.3626
# 13  0.5  0.7                      text        gene_synonym_symbol      0.3655
# 37  0.5  0.7           text_mesh_terms        gene_synonym_symbol      0.3655
# 60  0.5  0.3             text_keywords        gene_synonym_symbol      0.3565
# 84  0.5  0.3  text_keywords_mesh_terms        gene_synonym_symbol      0.3565
# 52  2.5  0.3             text_keywords                    english      0.3414
# 28  2.5  0.3           text_mesh_terms                    english      0.3414
# 76  2.5  0.3  text_keywords_mesh_terms                    english      0.3414
# 4   2.5  0.3                      text                    english      0.3414
# 61  0.5  0.7             text_keywords        gene_synonym_symbol      0.3583
# 85  0.5  0.7  text_keywords_mesh_terms        gene_synonym_symbol      0.3583
# 53  2.5  0.7             text_keywords                    english      0.3341
# 29  2.5  0.7           text_mesh_terms                    english      0.3341
# ..  ...  ...                       ...                        ...         ...
# 93  1.5  0.7  text_keywords_mesh_terms  gene_synonym_symbol_ortho      0.2629
# 23  2.5  0.7                      text  gene_synonym_symbol_ortho      0.2620
# 69  1.5  0.7             text_keywords  gene_synonym_symbol_ortho      0.2625
# 67  0.5  0.7             text_keywords  gene_synonym_symbol_ortho      0.2599
# 95  2.5  0.7  text_keywords_mesh_terms  gene_synonym_symbol_ortho      0.2575
# 71  2.5  0.7             text_keywords  gene_synonym_symbol_ortho      0.2574
# 32  1.5  0.3           text_mesh_terms           gene_synonym_all      0.1522
# 8   1.5  0.3                      text           gene_synonym_all      0.1536
# 10  2.5  0.3                      text           gene_synonym_all      0.1492
# 33  1.5  0.7           text_mesh_terms           gene_synonym_all      0.1490
# 34  2.5  0.3           text_mesh_terms           gene_synonym_all      0.1486
# 9   1.5  0.7                      text           gene_synonym_all      0.1485
# 11  2.5  0.7                      text           gene_synonym_all      0.1500
# 35  2.5  0.7           text_mesh_terms           gene_synonym_all      0.1499
# 31  0.5  0.7           text_mesh_terms           gene_synonym_all      0.1409
# 80  1.5  0.3  text_keywords_mesh_terms           gene_synonym_all      0.1446
# 58  2.5  0.3             text_keywords           gene_synonym_all      0.1442
# 82  2.5  0.3  text_keywords_mesh_terms           gene_synonym_all      0.1436
# 30  0.5  0.3           text_mesh_terms           gene_synonym_all      0.1430
# 6   0.5  0.3                      text           gene_synonym_all      0.1465
# 56  1.5  0.3             text_keywords           gene_synonym_all      0.1457
# 7   0.5  0.7                      text           gene_synonym_all      0.1428
# 81  1.5  0.7  text_keywords_mesh_terms           gene_synonym_all      0.1411
# 59  2.5  0.7             text_keywords           gene_synonym_all      0.1458
# 83  2.5  0.7  text_keywords_mesh_terms           gene_synonym_all      0.1458
# 57  1.5  0.7             text_keywords           gene_synonym_all      0.1403
# 78  0.5  0.3  text_keywords_mesh_terms           gene_synonym_all      0.1176
# 79  0.5  0.7  text_keywords_mesh_terms           gene_synonym_all      0.1206
# 54  0.5  0.3             text_keywords           gene_synonym_all      0.1168
# 55  0.5  0.7             text_keywords           gene_synonym_all      0.1189
#
#     recall_500  recall_1000  map_cut_1000  ndcg_cut_10    P_5
# 0       0.6799       0.7815        0.2971       0.5300  0.545
# 24      0.6799       0.7813        0.2971       0.5300  0.545
# 72      0.6796       0.7813        0.2971       0.5300  0.545
# 48      0.6796       0.7815        0.2971       0.5300  0.545
# 1       0.6765       0.7761        0.2945       0.5232  0.560
# 25      0.6765       0.7757        0.2944       0.5232  0.560
# 49      0.6759       0.7761        0.2944       0.5232  0.560
# 73      0.6759       0.7757        0.2943       0.5232  0.560
# 50      0.6606       0.7678        0.2856       0.5072  0.540
# 26      0.6606       0.7673        0.2856       0.5072  0.540
# 74      0.6606       0.7673        0.2856       0.5072  0.540
# 2       0.6606       0.7678        0.2856       0.5072  0.540
# 27      0.6572       0.7571        0.2804       0.5084  0.580
# 51      0.6572       0.7569        0.2804       0.5084  0.580
# 3       0.6572       0.7569        0.2804       0.5084  0.580
# 75      0.6572       0.7571        0.2804       0.5084  0.580
# 12      0.6752       0.7683        0.2730       0.5083  0.535
# 36      0.6755       0.7674        0.2729       0.5083  0.535
# 13      0.6748       0.7648        0.2678       0.5118  0.530
# 37      0.6748       0.7637        0.2675       0.5118  0.530
# 60      0.6752       0.7683        0.2664       0.4951  0.515
# 84      0.6755       0.7671        0.2663       0.4951  0.515
# 52      0.6362       0.7390        0.2649       0.4876  0.545
# 28      0.6362       0.7390        0.2649       0.4876  0.545
# 76      0.6362       0.7390        0.2649       0.4876  0.545
# 4       0.6362       0.7390        0.2649       0.4876  0.545
# 61      0.6748       0.7648        0.2610       0.4965  0.510
# 85      0.6745       0.7637        0.2608       0.4965  0.510
# 53      0.6298       0.7248        0.2599       0.4859  0.580
# 29      0.6298       0.7248        0.2599       0.4859  0.580
# ..         ...          ...           ...          ...    ...
# 93      0.5745       0.6692        0.1672       0.2820  0.300
# 23      0.5561       0.6553        0.1672       0.3166  0.380
# 69      0.5723       0.6665        0.1668       0.2864  0.315
# 67      0.5802       0.6705        0.1639       0.2820  0.335
# 95      0.5562       0.6560        0.1622       0.3018  0.355
# 71      0.5557       0.6554        0.1621       0.3018  0.355
# 32      0.3650       0.4791        0.0763       0.1579  0.185
# 8       0.3632       0.4719        0.0753       0.1571  0.185
# 10      0.3605       0.4603        0.0741       0.1613  0.170
# 33      0.3590       0.4702        0.0739       0.1664  0.195
# 34      0.3598       0.4651        0.0739       0.1613  0.170
# 9       0.3581       0.4649        0.0733       0.1649  0.195
# 11      0.3532       0.4571        0.0721       0.1542  0.210
# 35      0.3535       0.4588        0.0721       0.1542  0.210
# 31      0.3465       0.4690        0.0709       0.1582  0.200
# 80      0.3609       0.4749        0.0705       0.1346  0.150
# 58      0.3590       0.4592        0.0699       0.1492  0.150
# 82      0.3586       0.4642        0.0697       0.1492  0.150
# 30      0.3449       0.4568        0.0696       0.1450  0.165
# 6       0.3380       0.4495        0.0694       0.1670  0.200
# 56      0.3582       0.4681        0.0694       0.1338  0.150
# 7       0.3401       0.4577        0.0688       0.1721  0.210
# 81      0.3559       0.4669        0.0673       0.1320  0.155
# 59      0.3522       0.4563        0.0672       0.1333  0.170
# 83      0.3522       0.4576        0.0672       0.1333  0.170
# 57      0.3547       0.4624        0.0667       0.1304  0.155
# 78      0.3366       0.4494        0.0615       0.1123  0.125
# 79      0.3308       0.4630        0.0614       0.1183  0.150
# 54      0.3309       0.4431        0.0594       0.1164  0.135
# 55      0.3236       0.4506        0.0577       0.1170  0.145
#
# [96 rows x 10 columns]
